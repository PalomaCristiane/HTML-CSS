# %% [markdown]
# <a href="https://colab.research.google.com/github/PalomaCristiane/HTML-CSS/blob/main/aula01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Lista de Exercícios**

# %% [markdown]
# 1) Exercícios Soma

# %%
x=4
y=5

# %%
c=x+y
print ("x+y=",c)
# Out:
# x+y= 9

# %% [markdown]
# 2) Exercício Subtração

# %%
x=9
y=5
c=x-y
print("x-y=", c)
# Out:
# x-y= 4
